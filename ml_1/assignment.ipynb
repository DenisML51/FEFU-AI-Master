# %%
print(2 + 1)
# Out:
# Running cells with '.venv (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/DenisML51/Documents/Coding/FEFU-AI-Master/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
